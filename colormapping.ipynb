# %%
import PIL
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from keras import *
from keras.preprocessing.image import load_img, img_to_array

# %%
path="D:/All/sat_crop/output/cdl_2015245_1_13.tif/"

# %%
image= load_img(path)

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x18D9EFA25C0>

# %%
imggg=load_img(path)
imggg
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x18D9EE93630>

# %% [markdown]
# image=img_to_array(image)
# image=np.asarray(image)
# print(image.shape)
# image=image/255
# plt.imshow(image , cmap="gray")
# plt.show()

# %%
colormap = [["#000000","0","0"],
 ["#ffd300","1","1"],
 ["#ff2626","2","2"],
 ["#00a8e2","3","3"],
 ["#ff9e0a","4","4"],
 ["#267000","5","5"],
 ["#ffff00","6","6"],
 ["#000000","7","7"],
 ["#000000","8","8"],
 ["#000000","9","9"],
 ["#70a500","10","10"],
 ["#00af49","11","11"],
 ["#dda50a","12","12"],
 ["#dda50a","13","13"],
 ["#7cd3ff","14","14"],
 ["#000000","15","15"],
 ["#000000","16","16"],
 ["#000000","17","17"],
 ["#000000","18","18"],
 ["#000000","19","19"],
 ["#000000","20","20"],
 ["#e2007c","21","21"],
 ["#896054","22","22"],
 ["#d8b56b","23","23"],
 ["#a57000","24","24"],
 ["#d69ebc","25","25"],
 ["#707000","26","26"],
 ["#aa007c","27","27"],
 ["#a05989","28","28"],
 ["#700049","29","29"],
 ["#d69ebc","30","30"],
 ["#d1ff00","31","31"],
 ["#7c99ff","32","32"],
 ["#d6d600","33","33"],
 ["#d1ff00","34","34"],
 ["#00af49","35","35"],
 ["#ffa5e2","36","36"],
 ["#a5f28c","37","37"],
 ["#00af49","38","38"],
 ["#d69ebc","39","39"],
 ["#000000","40","40"],
 ["#a800e2","41","41"],
 ["#a50000","42","42"],
 ["#702600","43","43"],
 ["#00af49","44","44"],
 ["#af7cff","45","45"],
 ["#702600","46","46"],
 ["#ff6666","47","47"],
 ["#ff6666","48","48"],
 ["#ffcc66","49","49"],
 ["#ff6666","50","50"],
 ["#00af49","51","51"],
 ["#00ddaf","52","52"],
 ["#54ff00","53","53"],
 ["#f2a377","54","54"],
 ["#ff6666","55","55"],
 ["#00af49","56","56"],
 ["#7cd3ff","57","57"],
 ["#e8bfff","58","58"],
 ["#afffdd","59","59"],
 ["#00af49","60","60"],
 ["#bfbf77","61","61"],
 ["#000000","62","62"],
 ["#93cc93","63","63"],
 ["#c6d69e","64","64"],
 ["#ccbfa3","65","65"],
 ["#ff00ff","66","66"],
 ["#ff8eaa","67","67"],
 ["#ba004f","68","68"],
 ["#704489","69","69"],
 ["#007777","70","70"],
 ["#af9970","71","71"],
 ["#ffff7c","72","72"],
 ["#000000","73","73"],
 ["#b5705b","74","74"],
 ["#00a582","75","75"],
 ["#e8d6af","76","76"],
 ["#af9970","77","77"],
 ["#000000","78","78"],
 ["#000000","79","79"],
 ["#000000","80","80"],
 ["#f2f2f2","81","81"],
 ["#999999","82","82"],
 ["#4970a3","83","83"],
 ["#000000","84","84"],
 ["#000000","85","85"],
 ["#000000","86","86"],
 ["#7cafaf","87","87"],
 ["#e8ffbf","88","88"],
 ["#000000","89","89"],
 ["#000000","90","90"],
 ["#000000","91","91"],
 ["#00ffff","92","92"],
 ["#000000","93","93"],
 ["#000000","94","94"],
 ["#000000","95","95"],
 ["#000000","96","96"],
 ["#000000","97","97"],
 ["#000000","98","98"],
 ["#000000","99","99"],
 ["#000000","100","100"],
 ["#000000","101","101"],
 ["#000000","102","102"],
 ["#000000","103","103"],
 ["#000000","104","104"],
 ["#000000","105","105"],
 ["#000000","106","106"],
 ["#000000","107","107"],
 ["#000000","108","108"],
 ["#000000","109","109"],
 ["#000000","110","110"],
 ["#4970a3","111","111"],
 ["#d3e2f9","112","112"],
 ["#000000","113","113"],
 ["#000000","114","114"],
 ["#000000","115","115"],
 ["#000000","116","116"],
 ["#000000","117","117"],
 ["#000000","118","118"],
 ["#000000","119","119"],
 ["#000000","120","120"],
 ["#999999","121","121"],
 ["#999999","122","122"],
 ["#999999","123","123"],
 ["#999999","124","124"],
 ["#000000","125","125"],
 ["#000000","126","126"],
 ["#000000","127","127"],
 ["#000000","128","128"],
 ["#000000","129","129"],
 ["#000000","130","130"],
 ["#ccbfa3","131","131"],
 ["#000000","132","132"],
 ["#000000","133","133"],
 ["#000000","134","134"],
 ["#000000","135","135"],
 ["#000000","136","136"],
 ["#000000","137","137"],
 ["#000000","138","138"],
 ["#000000","139","139"],
 ["#000000","140","140"],
 ["#93cc93","141","141"],
 ["#93cc93","142","142"],
 ["#93cc93","143","143"],
 ["#000000","144","144"],
 ["#000000","145","145"],
 ["#000000","146","146"],
 ["#000000","147","147"],
 ["#000000","148","148"],
 ["#000000","149","149"],
 ["#000000","150","150"],
 ["#000000","151","151"],
 ["#c6d69e","152","152"],
 ["#000000","153","153"],
 ["#000000","154","154"],
 ["#000000","155","155"],
 ["#000000","156","156"],
 ["#000000","157","157"],
 ["#000000","158","158"],
 ["#000000","159","159"],
 ["#000000","160","160"],
 ["#000000","161","161"],
 ["#000000","162","162"],
 ["#000000","163","163"],
 ["#000000","164","164"],
 ["#000000","165","165"],
 ["#000000","166","166"],
 ["#000000","167","167"],
 ["#000000","168","168"],
 ["#000000","169","169"],
 ["#000000","170","170"],
 ["#000000","171","171"],
 ["#000000","172","172"],
 ["#000000","173","173"],
 ["#000000","174","174"],
 ["#000000","175","175"],
 ["#e8ffbf","176","176"],
 ["#000000","177","177"],
 ["#000000","178","178"],
 ["#000000","179","179"],
 ["#000000","180","180"],
 ["#000000","181","181"],
 ["#000000","182","182"],
 ["#000000","183","183"],
 ["#000000","184","184"],
 ["#000000","185","185"],
 ["#000000","186","186"],
 ["#000000","187","187"],
 ["#000000","188","188"],
 ["#000000","189","189"],
 ["#7cafaf","190","190"],
 ["#000000","191","191"],
 ["#000000","192","192"],
 ["#000000","193","193"],
 ["#000000","194","194"],
 ["#7cafaf","195","195"],
 ["#000000","196","196"],
 ["#000000","197","197"],
 ["#000000","198","198"],
 ["#000000","199","199"],
 ["#000000","200","200"],
 ["#000000","201","201"],
 ["#000000","202","202"],
 ["#000000","203","203"],
 ["#00ff8c","204","204"],
 ["#d69ebc","205","205"],
 ["#ff6666","206","206"],
 ["#ff6666","207","207"],
 ["#ff6666","208","208"],
 ["#ff6666","209","209"],
 ["#ff8eaa","210","210"],
 ["#334933","211","211"],
 ["#e27026","212","212"],
 ["#ff6666","213","213"],
 ["#ff6666","214","214"],
 ["#000000","215","215"],
 ["#ff6666","216","216"],
 ["#af9970","217","217"],
 ["#ff8eaa","218","218"],
 ["#ff6666","219","219"],
 ["#ff8eaa","220","220"],
 ["#ff6666","221","221"],
 ["#ff6666","222","222"],
 ["#ff8eaa","223","223"],
 ["#00af49","224","224"],
 ["#ffd300","225","225"],
 ["#ffd300","226","226"],
 ["#ff6666","227","227"],
 ["#000000","228","228"],
 ["#ff6666","229","229"],
 ["#896054","230","230"],
 ["#ff6666","231","231"],
 ["#ff2626","232","232"],
 ["#e2007c","233","233"],
 ["#ff9e0a","234","234"],
 ["#ff9e0a","235","235"],
 ["#a57000","236","236"],
 ["#ffd300","237","237"],
 ["#a57000","238","238"],
 ["#267000","239","239"],
 ["#267000","240","240"],
 ["#ffd300","241","241"],
 ["#000099","242","242"],
 ["#ff6666","243","243"],
 ["#ff6666","244","244"],
 ["#ff6666","245","245"],
 ["#ff6666","246","246"],
 ["#ff6666","247","247"],
 ["#ff6666","248","248"],
 ["#ff6666","249","249"],
 ["#ff6666","250","250"],
 ["#ffd300","251","251"],
 ["#267000","252","252"],
 ["#a57000","253","253"],
 ["#267000","254","254"],
 ["#707000","255","255"]]


def hex_to_rgb(value):
 value = value.lstrip('#')
 lv = len(value)
 return list(int(value[i:i + lv // 3], 16) for i in range(0, lv, lv // 3))



def getCDLRGB(cdlvalue):
 # print("get cdl:", cdlvalue)
 for x in range(len(colormap)):
   if(int(colormap[x][1])==cdlvalue):
    hex = colormap[x][0]
    rgb = hex_to_rgb(hex)
    return rgb

print("The color of class 5 is: ", getCDLRGB(213));
# Out:
# The color of class 5 is:  [255, 102, 102]

# %%
imggg
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x18D9EE93630>

# %%
lstt=[[[ 1 for _ in range(3)]for _ in range(128) ] for _ in range(128)]

for i in range(128):
    for j in range(128):
        cdlval=int(image[i][j][0])
        print(cdlval)
        print(list(getCDLRGB(cdlval)))
        
        lstt[i][j]=list(getCDLRGB(cdlval))
lstt 
lstt= np.asarray(lstt)
plt.imshow(lstt)
plt.show()
# Out:
# 5
# [38, 112, 0]
# 5
# [38, 112, 0]
# 5
# [38, 112, 0]
# 5
# [38, 112, 0]
# 5
# [38, 112, 0]
# 5
# [38, 112, 0]
# 5
# [38, 112, 0]
# 37
# [165, 242, 140]
# 37
# [165, 242, 140]
# 176
# [232, 255, 191]
# 176
# [232, 255, 191]
# 37
# [165, 242, 140]
# 37
# [165, 242, 140]
# 37
# [165, 242, 140]
# 176
# [232, 255, 191]
# 176
# [232, 255, 191]
# 176
# [232, 255, 191]
# 176
# [232, 255, 191]
# 195
# [124, 175, 175]
# 195
# [124, 175, 175]
# 195
# [124, 175, 175]
# 111
# [73, 112, 163]
# 195
# [124, 175, 175]
# 195
# [124, 175, 175]
# 61
# [191, 191, 119]
# 195
# [124, 175, 175]
# 195
# [124, 175, 175]
# 195
# [124, 175, 175]
# 195
# [124, 175, 175]
# 111
# [73, 112, 163]
# 111
# [73, 112, 163]
# 195
# [124, 175, 175]
# 195
# [124, 175, 175]
# 195
# [124, 175, 175]
# 195
# [124, 175, 175]
# 195
# [124, 175, 175]
# 195
# [124, 175, 175]
# 195
# [124, 175, 175]
# 195
# [124, 175, 175]
# 195
# [124, 175, 175]
# 195
# [124, 175, 175]
# 195
# [124, 175, 175]
# 195
# [124, 175, 175]
# 195
# ...

# %%
image
# Out:
# array([[[nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         ...,
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan]],
#
#        [[nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         ...,
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan]],
#
#        [[nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         ...,
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan]],
#
#        ...,
#
#        [[nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         ...,
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan]],
#
#        [[nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         ...,
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan]],
#
#        [[nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
# ...
